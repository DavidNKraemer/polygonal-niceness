# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
input_dir = '../data/input/10/'

# %%
ls ../data/input/10/
# Out:
# 10.poly   1s.poly  3.poly   4s.poly  6.poly   7s.poly  9.poly
# 10s.poly  2.poly   3s.poly  5.poly   6s.poly  8.poly   9s.poly
# 1.poly    2s.poly  4.poly   5s.poly  7.poly   8s.poly

# %%
polygons = []
polygons_s = []
for i in range(1,11):
    polygons.append(np.loadtxt(input_dir + '{}.poly'.format(i), skiprows=1))
    polygons_s.append(np.loadtxt(input_dir + '{}s.poly'.format(i), skiprows=1))

# %%
plt.plot(polygons_s[0][:,0],polygons_s[0][:,1])
plt.plot(polygons[0][:,0],polygons[0][:,1])
